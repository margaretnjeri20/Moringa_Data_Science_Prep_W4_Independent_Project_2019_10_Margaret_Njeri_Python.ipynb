# %% [markdown]
# <a href="https://colab.research.google.com/github/margaretnjeri20/Moringa_Data_Science_Prep_W4_Independent_Project_2019_10_Margaret_Njeri_Python.ipynb/blob/master/Moringa_Data_Science_Prep_W4_Independent_Project_2019_10_Margaret_Njeri_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#displaying the dataset from the url.
url = 'Autolib_dataset.csv'
autolib_df = pd.read_csv(url)
autolib_df
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue EugÃ¨ne OudinÃ©     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue MÃ©nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
#displaying the first 10 rows.
autolib_df.head(10)
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue EugÃ¨ne OudinÃ©     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
# 5                8 Boulevard Voltaire     0                0  ...    6     7       2
# 6                      37 rue Leblanc     0                0  ...    8    18      20
# 7         17 Rue des Luaps ProlongÃ©e     3                3  ...    4    22      13
# 8               34 avenue Jean Moulin     1                1  ...    2    22      58
# 9        41 boulevard de Rochechouart     6                6  ...    4    15       2
#
# [10 rows x 25 columns]

# %%
#getting a summarized information on the dataset.
autolib_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
# Address                5000 non-null object
# Cars                   5000 non-null int64
# Bluecar counter        5000 non-null int64
# Utilib counter         5000 non-null int64
# Utilib 1.4 counter     5000 non-null int64
# Charge Slots           5000 non-null int64
# Charging Status        5000 non-null object
# City                   5000 non-null object
# Displayed comment      111 non-null object
# ID                     5000 non-null object
# Kind                   5000 non-null object
# Geo point              5000 non-null object
# Postal code            5000 non-null int64
# Public name            5000 non-null object
# Rental status          5000 non-null object
# Scheduled at           47 non-null object
# Slots                  5000 non-null int64
# Station type           5000 non-null object
# Status                 5000 non-null object
# ...

# %%
#finding out how many null values are there. 
autolib_df.isnull().sum()
# Out:
# Address                   0
# Cars                      0
# Bluecar counter           0
# Utilib counter            0
# Utilib 1.4 counter        0
# Charge Slots              0
# Charging Status           0
# City                      0
# Displayed comment      4889
# ID                        0
# Kind                      0
# Geo point                 0
# Postal code               0
# Public name               0
# Rental status             0
# Scheduled at           4953
# Slots                     0
# Station type              0
# Status                    0
# Subscription status       0
# year                      0
# month                     0
# day                       0
# hour                      0
# minute                    0
# dtype: int64

# %%
#dropping null columns.
autolib_drop = autolib_df.dropna(axis = 1, how = 'all') 
autolib_drop
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue EugÃ¨ne OudinÃ©     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue MÃ©nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
autolib_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
# Address                5000 non-null object
# Cars                   5000 non-null int64
# Bluecar counter        5000 non-null int64
# Utilib counter         5000 non-null int64
# Utilib 1.4 counter     5000 non-null int64
# Charge Slots           5000 non-null int64
# Charging Status        5000 non-null object
# City                   5000 non-null object
# Displayed comment      111 non-null object
# ID                     5000 non-null object
# Kind                   5000 non-null object
# Geo point              5000 non-null object
# Postal code            5000 non-null int64
# Public name            5000 non-null object
# Rental status          5000 non-null object
# Scheduled at           47 non-null object
# Slots                  5000 non-null int64
# Station type           5000 non-null object
# Status                 5000 non-null object
# ...

# %%
#dropping irrelevant columns.
autolib_dropped = autolib_df.drop(['Scheduled at', 'Status', 'Displayed comment','Charging Status','Station type','Subscription status','Kind','Rental status'],axis = 1)
autolib_dropped.head(10)
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue EugÃ¨ne OudinÃ©     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
# 5                8 Boulevard Voltaire     0                0  ...    6     7       2
# 6                      37 rue Leblanc     0                0  ...    8    18      20
# 7         17 Rue des Luaps ProlongÃ©e     3                3  ...    4    22      13
# 8               34 avenue Jean Moulin     1                1  ...    2    22      58
# 9        41 boulevard de Rochechouart     6                6  ...    4    15       2
#
# [10 rows x 17 columns]

# %%
autolib_dropped.tail()
# Out:
#                           Address  Cars  Bluecar counter  ...  day  hour  minute
# 4995          8 avenue MÃ©nelotte     2                2  ...    6    11      26
# 4996            37 rue de Dantzig     4                4  ...    4    16      56
# 4997               142 rue du Bac     1                1  ...    1     7       1
# 4998  2 avenue du Val de Fontenay     2                2  ...    4    17      27
# 4999          5 Rue Henry Brisson     4                4  ...    8    10       2
#
# [5 rows x 17 columns]

# %%
#completeness
autolib_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
# Address               5000 non-null object
# Cars                  5000 non-null int64
# Bluecar counter       5000 non-null int64
# Utilib counter        5000 non-null int64
# Utilib 1.4 counter    5000 non-null int64
# Charge Slots          5000 non-null int64
# City                  5000 non-null object
# ID                    5000 non-null object
# Geo point             5000 non-null object
# Postal code           5000 non-null int64
# Public name           5000 non-null object
# Slots                 5000 non-null int64
# year                  5000 non-null int64
# month                 5000 non-null int64
# day                   5000 non-null int64
# hour                  5000 non-null int64
# minute                5000 non-null int64
# dtypes: int64(12), object(5)
# memory usage: 664.2+ KB

# %%
autolib_dropped.isnull().sum()
# Out:
# Address               0
# Cars                  0
# Bluecar counter       0
# Utilib counter        0
# Utilib 1.4 counter    0
# Charge Slots          0
# City                  0
# ID                    0
# Geo point             0
# Postal code           0
# Public name           0
# Slots                 0
# year                  0
# month                 0
# day                   0
# hour                  0
# minute                0
# dtype: int64

# %%
autolib_dropped.notnull().sum()
# Out:
# Address               5000
# Cars                  5000
# Bluecar counter       5000
# Utilib counter        5000
# Utilib 1.4 counter    5000
# Charge Slots          5000
# City                  5000
# ID                    5000
# Geo point             5000
# Postal code           5000
# Public name           5000
# Slots                 5000
# year                  5000
# month                 5000
# day                   5000
# hour                  5000
# minute                5000
# dtype: int64

# %%
#checking for Consistency
#checking 
autolib_dropped.duplicated().sum()
# Out:
# 0

# %%
autolib_df = autolib_dropped.drop_duplicates()
autolib_df
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue EugÃ¨ne OudinÃ©     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue MÃ©nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 17 columns]

# %%
autolib_df.duplicated().sum()
# Out:
# 0

# %%
# uniformity 
#converting column names to lower case
autolib_df.columns = autolib_df.columns.str.lower()
autolib_df.head()
# Out:
#                               address  cars  bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue EugÃ¨ne OudinÃ©     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
#
# [5 rows x 17 columns]

# %%
# confirming the data after cleaning.
autolib_df.sum()
# Out:
# address               2 Avenue de Suffren145 Rue Raymond Losserand2 ...
# cars                                                              11668
# bluecar counter                                                   11668
# utilib counter                                                      298
# utilib 1.4 counter                                                  615
# charge slots                                                       1267
# city                  ParisParisLe BourgetParisParisParisParisNanter...
# id                    paris-suffren-2paris-raymondlosserand-145lebou...
# geo point             48.857, 2.291748.83126, 2.31308848.938103, 2.4...
# postal code                                                   413174392
# public name           Paris/Suffren/2Paris/Raymond Losserand/145Le B...
# slots                                                              9662
# year                                                           10090000
# ...

# %%
autolib_df['minute'].min()
# Out:
# 0

# %%
autolib_df['minute'].max()
# Out:
# 59

# %%
autolib_df['hour'].min()
# Out:
# 0

# %%
autolib_df['hour'].max()
# Out:
# 23

# %%
autolib_df1.isnull().sum()
# Out:
# address               0
# cars                  0
# bluecar counter       0
# utilib counter        0
# utilib 1.4 counter    0
# charge slots          0
# city                  0
# id                    0
# geo point             0
# postal code           0
# public name           0
# slots                 0
# year                  0
# month                 0
# day                   0
# hour                  0
# minute                0
# dtype: int64

# %%
# Analysis.
# Most popular hour for picking up a bluecar

autolib_df1 = autolib_df[autolib_df['city'] == 'Paris']

# %%
autolib_df2 = autolib_df1.groupby(['public name', 'hour'])[['bluecar counter']].sum()
autolib_df2.head()
# Out:
#                             bluecar counter
# public name           hour
# Paris/25 AoÃ»t 1944/8 3                   3
#                       5                   0
#                       7                   4
#                       12                  2
#                       18                  2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# use Seaborn styles
sns.set()
# getting the number of cars that are there in each hour in order to get the exact popular hour.
pd.pivot_table(autolib_df, index= 'hour', values= "cars",aggfunc='count').plot(kind= 'bar')
plt.ylabel("number of cars")
# Out:
# Text(0, 0.5, 'number of cars')

# %%
pd.pivot_table(autolib_df1, index= ['utilib 1.4 counter'], values= "cars",aggfunc='count').plot(kind= 'bar')

# %%
#the most popular geo point.
autolib_df1['geo point'].mode()
# Out:
# 0    48.8230593, 2.322823
# dtype: object

# %%
#getting unique value in bluecar counter.
autolib_df['bluecar counter'].unique()
# Out:
# array([0, 6, 3, 1, 5, 4, 2, 7])

# %%
autolib_df['hour'].unique()
# Out:
# array([11,  7, 20,  4, 17, 18, 22, 15,  9, 12, 21,  8,  0, 19,  6,  3, 23,
#         2,  1, 10, 16, 13, 14,  5])
